# %%
# install dependencies (local or Colab)
# !pip install --upgrade pip
# !pip install pandas numpy scikit-learn joblib openpyxl
# !pip install tensorflow   # required for Keras LSTM
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# ==============================
# 1. Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Dropout, Masking, Flatten

# ==============================
# 2. Load Data
# ==============================
file_path = "/content/final.xlsx"
df = pd.read_excel(file_path)

print("Data shape:", df.shape)
print("Columns:", df.columns.tolist())

# ==============================
# 3. Columns Setup
# ==============================
company_col = "Company"
date_col = "FiscalDate"
TARGETS = [
    "Risk_Score",
    "Growth_Score",
    "Profitability_Score",
    "Stability_Score",
    "Sector_Score",
    "Overall_Score",
]

# Convert date and sort
df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
df = df.sort_values(by=[company_col, date_col])

# ==============================
# 4. Handle Missing Values
# ==============================
for col in TARGETS:
    df[col] = df.groupby(company_col)[col].transform(lambda g: g.ffill().bfill())

# Drop rows still missing
df = df.dropna(subset=TARGETS)

# ==============================
# 5. Encode Company
# ==============================
le = LabelEncoder()
df["Company_Encoded"] = le.fit_transform(df[company_col])

# ==============================
# 6. Scaling Targets
# ==============================
scaler = StandardScaler()
df[TARGETS] = scaler.fit_transform(df[TARGETS])

# ==============================
# 7. Sequence Builder (12 quarters)
# ==============================
SEQ_LEN = 12

def create_sequences(group):
    X, y, comp = [], [], []
    values = group[TARGETS].values
    company_id = group["Company_Encoded"].values[0]
    for i in range(len(values) - SEQ_LEN):
        X.append(values[i:i+SEQ_LEN])
        y.append(values[i+SEQ_LEN])  # next quarter
        comp.append(company_id)
    return np.array(X), np.array(y), np.array(comp)

X_list, y_list, comp_list = [], [], []
for _, g in df.groupby(company_col):
    X_g, y_g, comp_g = create_sequences(g)
    if len(X_g) > 0:
        X_list.append(X_g)
        y_list.append(y_g)
        comp_list.append(comp_g)

X = np.vstack(X_list)
y = np.vstack(y_list)
companies = np.concatenate(comp_list)

print("Sequences shape:", X.shape, y.shape)

# ==============================
# 8. Train/Test Split
# ==============================
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
comp_train, comp_test = companies[:split], companies[split:]

# ==============================
# 9. LSTM Model
# ==============================
num_companies = df["Company_Encoded"].nunique()
embed_dim = 8

# Inputs
input_seq = Input(shape=(SEQ_LEN, len(TARGETS)))
input_comp = Input(shape=(1,))

# Company embedding
x_comp = Embedding(input_dim=num_companies, output_dim=embed_dim)(input_comp)
x_comp = Flatten()(x_comp)

# Sequence path
x_seq = Masking()(input_seq)
x_seq = LSTM(64, return_sequences=False)(x_seq)
x_seq = Dropout(0.3)(x_seq)

# Merge
x = Concatenate()([x_seq, x_comp])
x = Dense(64, activation="relu")(x)
output = Dense(len(TARGETS))(x)

model = Model(inputs=[input_seq, input_comp], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss="mse")

model.summary()

# ==============================
# 10. Training
# ==============================
history = model.fit(
    [X_train, comp_train],
    y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=32,
    verbose=1
)

# ==============================
# 11. Evaluation
# ==============================
preds = model.predict([X_test, comp_test])

print("\nMAE per Score:")
for i, col in enumerate(TARGETS):
    mae = mean_absolute_error(y_test[:, i], preds[:, i])
    print(f"{col}: {mae:.4f}")

# ==============================
# 12. Visualization
# ==============================
n_plot = 200  # number of points to plot
plt.figure(figsize=(14, 8))
for i, col in enumerate(TARGETS):
    plt.subplot(2, 3, i+1)
    plt.plot(y_test[:n_plot, i], label="Actual")
    plt.plot(preds[:n_plot, i], label="Predicted")
    plt.title(col)
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Data shape: (7574, 24)
# Columns: ['FiscalDate', 'Company', 'Sector', 'Revenue', 'Expenses', 'EBITDA', 'Operating Margin %', 'Depreciation', 'Interest', 'PBT', 'Tax', 'Net Profit', 'EPS', 'GST', 'CorpTax%', 'Inflation%', 'RepoRate%', 'USDINR_Close', 'Risk_Score', 'Growth_Score', 'Profitability_Score', 'Stability_Score', 'Sector_Score', 'Overall_Score']
# Sequences shape: (4765, 12, 6) (4765, 6)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 12, 6)     │          0 │ input_layer[0][0] │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 12, 6)     │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 12)        │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     18,176 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 1, 8)      │      1,944 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 8)         │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 72)        │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      4,672 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 6)         │        390 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,182 (98.37 KB)
#  Trainable params: 25,182 (98.37 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.7562 - val_loss: 0.3242
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.6817 - val_loss: 0.3092
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.8715 - val_loss: 0.2922
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6831 - val_loss: 0.2955
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5312 - val_loss: 0.2866
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7421 - val_loss: 0.2859
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6876 - val_loss: 0.2824
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6816 - val_loss: 0.2851
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5665 - val_loss: 0.2879
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5740 - val_loss: 0.2930
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8040 - val_loss: 0.2860
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.5771 - val_loss: 0.2890
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5767 - val_loss: 0.2911
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5696 - val_loss: 0.2924
# Epoch 15/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4361 - val_loss: 0.3032
# Epoch 16/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5586 - val_loss: 0.2988
# Epoch 17/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5208 - val_loss: 0.3066
# Epoch 18/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4281 - val_loss: 0.3199
# Epoch 19/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4836 - val_loss: 0.3123
# Epoch 20/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.4595 - val_loss: 0.3131
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# MAE per Score:
# Risk_Score: 0.1774
# Growth_Score: 0.5755
# Profitability_Score: 0.2682
# Stability_Score: 0.3598
# Sector_Score: 0.4797
# Overall_Score: 0.3237

# %%
# ==============================
# 1. Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Dropout, Masking, Flatten

# ==============================
# 2. Load Data
# ==============================
file_path = "/content/final.xlsx"
df = pd.read_excel(file_path)

print("Data shape:", df.shape)
print("Columns:", df.columns.tolist())

# ==============================
# 3. Columns Setup
# ==============================
company_col = "Company"
date_col = "FiscalDate"
TARGETS = [
    "Risk_Score",
    "Growth_Score",
    "Profitability_Score",
    "Stability_Score",
    "Sector_Score",
    "Overall_Score",
]

# Convert date and sort
df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
df = df.sort_values(by=[company_col, date_col])

# ==============================
# 4. Handle Missing Values
# ==============================
for col in TARGETS:
    df[col] = df.groupby(company_col)[col].transform(lambda g: g.ffill().bfill())

# Drop rows still missing
df = df.dropna(subset=TARGETS)

# ==============================
# 5. Encode Company
# ==============================
le = LabelEncoder()
df["Company_Encoded"] = le.fit_transform(df[company_col])

# ==============================
# 6. Scaling Targets
# ==============================
scaler = StandardScaler()
df[TARGETS] = scaler.fit_transform(df[TARGETS])

# ==============================
# 7. Sequence Builder (16 quarters)
# ==============================
SEQ_LEN = 16

def create_sequences(group):
    X, y, comp = [], [], []
    values = group[TARGETS].values
    company_id = group["Company_Encoded"].values[0]
    for i in range(len(values) - SEQ_LEN):
        X.append(values[i:i+SEQ_LEN])
        y.append(values[i+SEQ_LEN])  # next quarter
        comp.append(company_id)
    return np.array(X), np.array(y), np.array(comp)

X_list, y_list, comp_list = [], [], []
for _, g in df.groupby(company_col):
    X_g, y_g, comp_g = create_sequences(g)
    if len(X_g) > 0:
        X_list.append(X_g)
        y_list.append(y_g)
        comp_list.append(comp_g)

X = np.vstack(X_list)
y = np.vstack(y_list)
companies = np.concatenate(comp_list)

print("Sequences shape:", X.shape, y.shape)

# ==============================
# 8. Train/Test Split
# ==============================
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
comp_train, comp_test = companies[:split], companies[split:]

# ==============================
# 9. Improved LSTM Model (tuned for Stability)
# ==============================
num_companies = df["Company_Encoded"].nunique()
embed_dim = 8

# Inputs
input_seq = Input(shape=(SEQ_LEN, len(TARGETS)))
input_comp = Input(shape=(1,))

# Company embedding
x_comp = Embedding(input_dim=num_companies, output_dim=embed_dim)(input_comp)
x_comp = Flatten()(x_comp)

# Sequence path - stacked LSTMs (adjusted for Stability)
x_seq = Masking()(input_seq)
x_seq = LSTM(64, return_sequences=True)(x_seq)
x_seq = Dropout(0.3)(x_seq)          # keep regularization
x_seq = LSTM(48)(x_seq)              # bigger layer for smoother memory
x_seq = Dropout(0.2)(x_seq)          # reduced dropout (less information loss)

# Merge
x = Concatenate()([x_seq, x_comp])

# Residual dense block
dense1 = Dense(64, activation="relu")(x)
dense1 = BatchNormalization()(dense1)
dense1 = Dropout(0.3)(dense1)
dense2 = Dense(32, activation="relu")(dense1)
dense2 = BatchNormalization()(dense2)
dense2 = Dropout(0.3)(dense2)

# Final output
output = Dense(len(TARGETS))(dense2)

model = Model(inputs=[input_seq, input_comp], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")

model.summary()

# ==============================
# 10. Training with Callbacks
# ==============================
es = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
rlr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-5)

history = model.fit(
    [X_train, comp_train],
    y_train,
    validation_split=0.2,
    epochs=100,  # let EarlyStopping decide
    batch_size=32,
    verbose=1,
    callbacks=[es, rlr]
)

# ==============================
# 11. Evaluation
# ==============================
preds = model.predict([X_test, comp_test])

print("\nMAE per Score:")
for i, col in enumerate(TARGETS):
    mae = mean_absolute_error(y_test[:, i], preds[:, i])
    print(f"{col}: {mae:.4f}")


# ==============================
# 12. Visualization
# ==============================
n_plot = 200  # number of points to plot
plt.figure(figsize=(14, 8))
for i, col in enumerate(TARGETS):
    plt.subplot(2, 3, i+1)
    plt.plot(y_test[:n_plot, i], label="Actual")
    plt.plot(preds[:n_plot, i], label="Predicted")
    plt.title(col)
    plt.legend()
plt.tight_layout()
plt.show()

# ==============================
# 13. Predict Future for a Company
# ==============================
def predict_future(company_name, df, model, scaler, SEQ_LEN=12):
    """
    Predict the next quarter's scores for a given company.
    """
    if company_name not in df[company_col].unique():
        raise ValueError(f"Company '{company_name}' not found in dataset.")

    # Get company data
    company_data = df[df[company_col] == company_name].sort_values(by=date_col)
    company_id = company_data["Company_Encoded"].iloc[0]

    if len(company_data) < SEQ_LEN:
        raise ValueError(f"Not enough data for {company_name}. Need at least {SEQ_LEN} quarters.")

    # Take last SEQ_LEN quarters
    last_seq = company_data[TARGETS].values[-SEQ_LEN:]
    last_seq = np.expand_dims(last_seq, axis=0)  # shape (1, SEQ_LEN, features)

    # Predict
    pred_scaled = model.predict([last_seq, np.array([[company_id]])])
    pred = scaler.inverse_transform(pred_scaled)[0]  # rescale back

    # Return as dictionary
    result = {col: round(val, 3) for col, val in zip(TARGETS, pred)}
    return result

# ==============================
# 14. Example Predictions
# ==============================
example_companies = df[company_col].unique()[:3]  # first 3 companies
for comp in example_companies:
    print(f"\nNext quarter prediction for {comp}:")
    print(predict_future(comp, df, model, scaler))
# Out:
# Data shape: (7574, 24)
# Columns: ['FiscalDate', 'Company', 'Sector', 'Revenue', 'Expenses', 'EBITDA', 'Operating Margin %', 'Depreciation', 'Interest', 'PBT', 'Tax', 'Net Profit', 'EPS', 'GST', 'CorpTax%', 'Inflation%', 'RepoRate%', 'USDINR_Close', 'Risk_Score', 'Growth_Score', 'Profitability_Score', 'Stability_Score', 'Sector_Score', 'Overall_Score']
# Sequences shape: (3927, 16, 6) (3927, 6)
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 16, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_6         │ (None, 16, 6)     │          0 │ input_layer_8[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_6 (Masking) │ (None, 16, 6)     │          0 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_6 (Any)         │ (None, 16)        │          0 │ not_equal_6[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 16, 64)    │     18,176 │ masking_6[0][0],  │
# │                     │                   │            │ any_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 16, 64)    │          0 │ lstm_5[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_9       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_6 (LSTM)       │ (None, 48)        │     21,696 │ dropout_16[0][0], │
# │                     │                   │            │ any_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 1, 8)      │      1,944 │ input_layer_9[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 48)        │          0 │ lstm_6[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_6 (Flatten) │ (None, 8)         │          0 │ embedding_4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 56)        │          0 │ dropout_17[0][0], │
# │ (Concatenate)       │                   │            │ flatten_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      3,648 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 32)        │      2,080 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 6)         │        198 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 48,126 (187.99 KB)
#  Trainable params: 47,934 (187.24 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 2.6840 - val_loss: 0.4614 - learning_rate: 0.0010
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.7072 - val_loss: 0.4444 - learning_rate: 0.0010
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.3926 - val_loss: 0.4208 - learning_rate: 0.0010
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1.1009 - val_loss: 0.3974 - learning_rate: 0.0010
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.0598 - val_loss: 0.3768 - learning_rate: 0.0010
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.1307 - val_loss: 0.3643 - learning_rate: 0.0010
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.0265 - val_loss: 0.3552 - learning_rate: 0.0010
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.9718 - val_loss: 0.3542 - learning_rate: 0.0010
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.9698 - val_loss: 0.3537 - learning_rate: 0.0010
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.9386 - val_loss: 0.3546 - learning_rate: 0.0010
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.8996 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.7875 - val_loss: 0.3469 - learning_rate: 0.0010
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.9646 - val_loss: 0.3427 - learning_rate: 0.0010
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.7537 - val_loss: 0.3407 - learning_rate: 0.0010
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.6860 - val_loss: 0.3392 - learning_rate: 0.0010
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.8244 - val_loss: 0.3323 - learning_rate: 0.0010
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.0501 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.8657 - val_loss: 0.3353 - learning_rate: 0.0010
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.5892 - val_loss: 0.3479 - learning_rate: 0.0010
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 1.0264 - val_loss: 0.3443 - learning_rate: 0.0010
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.7492 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.6335 - val_loss: 0.3233 - learning_rate: 5.0000e-04
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.8114 - val_loss: 0.3296 - learning_rate: 5.0000e-04
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.6411 - val_loss: 0.3216 - learning_rate: 5.0000e-04
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.8841 - val_loss: 0.3314 - learning_rate: 5.0000e-04
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.8221 - val_loss: 0.3220 - learning_rate: 5.0000e-04
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.6842 - val_loss: 0.3266 - learning_rate: 5.0000e-04
# Epoch 28/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.7452 - val_loss: 0.3250 - learning_rate: 5.0000e-04
# Epoch 29/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.7853 - val_loss: 0.3331 - learning_rate: 5.0000e-04
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.9615 - val_loss: 0.3262 - learning_rate: 2.5000e-04
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.6743 - val_loss: 0.3294 - learning_rate: 2.5000e-04
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.7357 - val_loss: 0.3277 - learning_rate: 2.5000e-04
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.6475 - val_loss: 0.3254 - learning_rate: 2.5000e-04
# Epoch 34/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.6879 - val_loss: 0.3300 - learning_rate: 2.5000e-04
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
#
# MAE per Score:
# Risk_Score: 0.1565
# Growth_Score: 0.5397
# Profitability_Score: 0.2846
# Stability_Score: 0.3475
# Sector_Score: 0.4797
# Overall_Score: 0.3337
# Next quarter prediction for aarti-drugs-ltd:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-927403357.py in <cell line: 0>()
#     213 for comp in example_companies:
#     214     print(f"\nNext quarter prediction for {comp}:")
# --> 215     print(predict_future(comp, df, model, scaler))
#
# /tmp/ipython-input-927403357.py in predict_future(company_name, df, model, scaler, SEQ_LEN)
#     200
#     201     # Predict
# --> 202     pred_scaled = model.predict([last_seq, np.array([[company_id]])])
#     203     pred = scaler.inverse_transform(pred_scaled)[0]  # rescale back
#     204
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#     125
#     126     return error_handler
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
# ==============================
# 1. Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Embedding, LSTM, Dense, Concatenate, Dropout,
    Masking, Flatten, BatchNormalization, Bidirectional
)

# ==============================
# 2. Load Data
# ==============================
file_path = "/content/final.xlsx"
df = pd.read_excel(file_path)

print("Data shape:", df.shape)
print("Columns:", df.columns.tolist())

# ==============================
# 3. Columns Setup
# ==============================
company_col = "Company"
date_col = "FiscalDate"

# Prediction Targets
TARGETS = [
    "Risk_Score",
    "Growth_Score",
    "Profitability_Score",
    "Stability_Score",
    "Sector_Score",
    "Overall_Score",
]

# Macroeconomic Features
MACRO_FEATURES = ["GST", "CorpTax%", "Inflation%", "RepoRate%", "USDINR_Close"]

# Sequence input features = Targets + Macro
SEQ_FEATURES = TARGETS + MACRO_FEATURES

# ==============================
# 4. Handle Missing Values
# ==============================
for col in SEQ_FEATURES:
    df[col] = df.groupby(company_col)[col].transform(lambda g: g.ffill().bfill())

# Drop rows still missing
df = df.dropna(subset=SEQ_FEATURES)

# ==============================
# 5. Encode Company
# ==============================
le = LabelEncoder()
df["Company_Encoded"] = le.fit_transform(df[company_col])

# ==============================
# 6. Scaling
# ==============================
scaler = StandardScaler()
df[SEQ_FEATURES] = scaler.fit_transform(df[SEQ_FEATURES])

# ==============================
# 7. Sequence Builder (16 quarters)
# ==============================
SEQ_LEN = 16

def create_sequences(group):
    X, y, comp = [], [], []
    values = group[SEQ_FEATURES].values
    targets = group[TARGETS].values
    company_id = group["Company_Encoded"].values[0]

    for i in range(len(values) - SEQ_LEN):
        X.append(values[i:i+SEQ_LEN])
        y.append(targets[i+SEQ_LEN])  # next quarter targets
        comp.append(company_id)

    return np.array(X), np.array(y), np.array(comp)

X_list, y_list, comp_list = [], [], []
for _, g in df.groupby(company_col):
    X_g, y_g, comp_g = create_sequences(g)
    if len(X_g) > 0:
        X_list.append(X_g)
        y_list.append(y_g)
        comp_list.append(comp_g)

X = np.vstack(X_list)
y = np.vstack(y_list)
companies = np.concatenate(comp_list)

print("Sequences shape:", X.shape, y.shape)

# ==============================
# 8. Train/Test Split
# ==============================
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
comp_train, comp_test = companies[:split], companies[split:]

# ==============================
# 9. BiLSTM Model with Residual Dense
# ==============================
num_companies = df["Company_Encoded"].nunique()
embed_dim = 8

# Inputs
input_seq = Input(shape=(SEQ_LEN, len(SEQ_FEATURES)))
input_comp = Input(shape=(1,))

# Company embedding
x_comp = Embedding(input_dim=num_companies, output_dim=embed_dim)(input_comp)
x_comp = Flatten()(x_comp)

# Sequence path - BiLSTM
x_seq = Masking()(input_seq)
x_seq = Bidirectional(LSTM(64, return_sequences=True))(x_seq)
x_seq = Dropout(0.3)(x_seq)
x_seq = Bidirectional(LSTM(48))(x_seq)
x_seq = Dropout(0.2)(x_seq)

# Merge
x = Concatenate()([x_seq, x_comp])

# Residual dense block
dense1 = Dense(64, activation="relu")(x)
dense1 = BatchNormalization()(dense1)
dense1 = Dropout(0.3)(dense1)
dense2 = Dense(32, activation="relu")(dense1)
dense2 = BatchNormalization()(dense2)
dense2 = Dropout(0.3)(dense2)

# Output layer
output = Dense(len(TARGETS))(dense2)

model = Model(inputs=[input_seq, input_comp], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")

model.summary()

# ==============================
# 10. Training with Callbacks
# ==============================
es = tf.keras.callbacks.EarlyStopping(patience=12, restore_best_weights=True)
rlr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=6, min_lr=1e-5)

history = model.fit(
    [X_train, comp_train],
    y_train,
    validation_split=0.2,
    epochs=120,
    batch_size=32,
    verbose=1,
    callbacks=[es, rlr]
)

# ==============================
# 11. Evaluation
# ==============================
preds = model.predict([X_test, comp_test])

print("\nMAE per Score:")
for i, col in enumerate(TARGETS):
    mae = mean_absolute_error(y_test[:, i], preds[:, i])
    print(f"{col}: {mae:.4f}")

# ==============================
# 12. Visualization
# ==============================
n_plot = 200
plt.figure(figsize=(14, 8))
for i, col in enumerate(TARGETS):
    plt.subplot(2, 3, i+1)
    plt.plot(y_test[:n_plot, i], label="Actual")
    plt.plot(preds[:n_plot, i], label="Predicted")
    plt.title(col)
    plt.legend()
plt.tight_layout()
plt.show()

# ==============================
# 13. Predict Future for a Company
# ==============================
def predict_future(company_name, df, model, scaler, SEQ_LEN=16):
    """
    Predict the next quarter's scores for a given company.
    Uses last SEQ_LEN quarters of TARGETS + MACRO features.
    """
    if company_name not in df[company_col].unique():
        raise ValueError(f"Company '{company_name}' not found in dataset.")

    # Get company data
    company_data = df[df[company_col] == company_name].sort_values(by=date_col)
    company_id = company_data["Company_Encoded"].iloc[0]

    if len(company_data) < SEQ_LEN:
        raise ValueError(f"Not enough data for {company_name}. Need at least {SEQ_LEN} quarters.")

    # Take last SEQ_LEN quarters
    last_seq = company_data[SEQ_FEATURES].values[-SEQ_LEN:]
    last_seq = np.expand_dims(last_seq, axis=0)  # shape (1, SEQ_LEN, features)

    # Predict
    pred_scaled = model.predict([last_seq, np.array([[company_id]])])
    pred = scaler.inverse_transform(
        np.concatenate([pred_scaled, np.zeros((1, len(MACRO_FEATURES)))], axis=1)
    )[0][:len(TARGETS)]  # inverse only targets part

    # Return as dictionary
    result = {col: round(val, 3) for col, val in zip(TARGETS, pred)}
    return result

# ==============================
# 14. Example Predictions
# ==============================
example_companies = df[company_col].unique()[:3]
for comp in example_companies:
    print(f"\nNext quarter prediction for {comp}:")
    print(predict_future(comp, df, model, scaler))
# Out:
# Data shape: (7574, 24)
# Columns: ['FiscalDate', 'Company', 'Sector', 'Revenue', 'Expenses', 'EBITDA', 'Operating Margin %', 'Depreciation', 'Interest', 'PBT', 'Tax', 'Net Profit', 'EPS', 'GST', 'CorpTax%', 'Inflation%', 'RepoRate%', 'USDINR_Close', 'Risk_Score', 'Growth_Score', 'Profitability_Score', 'Stability_Score', 'Sector_Score', 'Overall_Score']
# Sequences shape: (3927, 16, 11) (3927, 6)
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 16, 11)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_7         │ (None, 16, 11)    │          0 │ input_layer_10[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_7 (Masking) │ (None, 16, 11)    │          0 │ input_layer_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_7 (Any)         │ (None, 16)        │          0 │ not_equal_7[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 16, 128)   │     38,912 │ masking_7[0][0],  │
# │ (Bidirectional)     │                   │            │ any_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 16, 128)   │          0 │ bidirectional[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_11      │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 96)        │     67,968 │ dropout_20[0][0], │
# │ (Bidirectional)     │                   │            │ any_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_5         │ (None, 1, 8)      │      1,944 │ input_layer_11[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 96)        │          0 │ bidirectional_1[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_7 (Flatten) │ (None, 8)         │          0 │ embedding_5[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 104)       │          0 │ dropout_21[0][0], │
# │ (Concatenate)       │                   │            │ flatten_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64)        │      6,720 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 32)        │      2,080 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 6)         │        198 │ dropout_23[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,206 (461.74 KB)
#  Trainable params: 118,014 (460.99 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 2.9525 - val_loss: 0.4645 - learning_rate: 0.0010
# Epoch 2/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 1.5337 - val_loss: 0.4557 - learning_rate: 0.0010
# Epoch 3/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.6379 - val_loss: 0.4136 - learning_rate: 0.0010
# Epoch 4/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.3364 - val_loss: 0.3955 - learning_rate: 0.0010
# Epoch 5/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 1.2196 - val_loss: 0.3669 - learning_rate: 0.0010
# Epoch 6/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.0437 - val_loss: 0.3682 - learning_rate: 0.0010
# Epoch 7/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.8054 - val_loss: 0.3559 - learning_rate: 0.0010
# Epoch 8/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.2023 - val_loss: 0.3469 - learning_rate: 0.0010
# Epoch 9/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.9024 - val_loss: 0.3486 - learning_rate: 0.0010
# Epoch 10/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.8367 - val_loss: 0.3567 - learning_rate: 0.0010
# Epoch 11/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.7708 - val_loss: 0.3467 - learning_rate: 0.0010
# Epoch 12/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.7186 - val_loss: 0.3371 - learning_rate: 0.0010
# Epoch 13/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.6769 - val_loss: 0.3351 - learning_rate: 0.0010
# Epoch 14/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.7935 - val_loss: 0.3346 - learning_rate: 0.0010
# Epoch 15/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.6603 - val_loss: 0.3305 - learning_rate: 0.0010
# Epoch 16/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.6891 - val_loss: 0.3427 - learning_rate: 0.0010
# Epoch 17/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.8488 - val_loss: 0.3297 - learning_rate: 0.0010
# Epoch 18/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.7827 - val_loss: 0.3221 - learning_rate: 0.0010
# Epoch 19/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.9017 - val_loss: 0.3354 - learning_rate: 0.0010
# Epoch 20/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.5654 - val_loss: 0.3403 - learning_rate: 0.0010
# Epoch 21/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.8253 - val_loss: 0.3298 - learning_rate: 0.0010
# Epoch 22/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.7194 - val_loss: 0.3449 - learning_rate: 0.0010
# Epoch 23/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.6870 - val_loss: 0.4324 - learning_rate: 0.0010
# Epoch 24/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.7243 - val_loss: 0.3134 - learning_rate: 0.0010
# Epoch 25/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.6351 - val_loss: 0.3300 - learning_rate: 0.0010
# Epoch 26/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.7910 - val_loss: 0.3513 - learning_rate: 0.0010
# Epoch 27/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.6534 - val_loss: 0.3298 - learning_rate: 0.0010
# Epoch 28/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.6655 - val_loss: 0.4057 - learning_rate: 0.0010
# Epoch 29/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.6142 - val_loss: 0.3384 - learning_rate: 0.0010
# Epoch 30/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.6184 - val_loss: 0.3303 - learning_rate: 0.0010
# Epoch 31/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.9605 - val_loss: 0.3293 - learning_rate: 5.0000e-04
# Epoch 32/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.7026 - val_loss: 0.3644 - learning_rate: 5.0000e-04
# Epoch 33/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.6710 - val_loss: 0.3851 - learning_rate: 5.0000e-04
# Epoch 34/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.7046 - val_loss: 0.3648 - learning_rate: 5.0000e-04
# Epoch 35/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.5709 - val_loss: 0.3731 - learning_rate: 5.0000e-04
# Epoch 36/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.5926 - val_loss: 0.3530 - learning_rate: 5.0000e-04
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
#
# MAE per Score:
# Risk_Score: 0.1523
# Growth_Score: 0.5338
# Profitability_Score: 0.3437
# Stability_Score: 0.3374
# Sector_Score: 0.4906
# Overall_Score: 0.3629
# Next quarter prediction for aarti-drugs-ltd:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3977992066.py in <cell line: 0>()
#     224 for comp in example_companies:
#     225     print(f"\nNext quarter prediction for {comp}:")
# --> 226     print(predict_future(comp, df, model, scaler))
#
# /tmp/ipython-input-3977992066.py in predict_future(company_name, df, model, scaler, SEQ_LEN)
#     209
#     210     # Predict
# --> 211     pred_scaled = model.predict([last_seq, np.array([[company_id]])])
#     212     pred = scaler.inverse_transform(
#     213         np.concatenate([pred_scaled, np.zeros((1, len(MACRO_FEATURES)))], axis=1)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#     125
#     126     return error_handler
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
# ==============================
# 1. Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Embedding, LSTM, Dense, Concatenate, Dropout,
    Masking, Flatten, BatchNormalization, Bidirectional
)

# ==============================
# 2. Load Data
# ==============================
file_path = "/content/final.xlsx"
df = pd.read_excel(file_path)

print("Data shape:", df.shape)
print("Columns:", df.columns.tolist())

# ==============================
# 3. Columns Setup
# ==============================
company_col = "Company"
date_col = "FiscalDate"

TARGETS = [
    "Risk_Score",
    "Growth_Score",
    "Profitability_Score",
    "Stability_Score",
    "Sector_Score",
    "Overall_Score",
]

MACRO_FEATURES = ["GST", "CorpTax%", "Inflation%", "RepoRate%", "USDINR_Close"]

SEQ_FEATURES = TARGETS + MACRO_FEATURES

# ==============================
# 4. Handle Missing Values
# ==============================
for col in SEQ_FEATURES:
    df[col] = df.groupby(company_col)[col].transform(lambda g: g.ffill().bfill())

df = df.dropna(subset=SEQ_FEATURES)

# ==============================
# 5. Encode Company
# ==============================
le = LabelEncoder()
df["Company_Encoded"] = le.fit_transform(df[company_col])

# ==============================
# 6. Scaling (X features vs y targets separately)
# ==============================
scaler_X = StandardScaler()
scaler_y = StandardScaler()

df[SEQ_FEATURES] = scaler_X.fit_transform(df[SEQ_FEATURES])

# We’ll fit y scaler later on y_train
# ==============================
# 7. Sequence Builder (16 quarters)
# ==============================
SEQ_LEN = 16

def create_sequences(group):
    X, y, comp = [], [], []
    values = group[SEQ_FEATURES].values
    targets = group[TARGETS].values
    company_id = group["Company_Encoded"].values[0]

    for i in range(len(values) - SEQ_LEN):
        X.append(values[i:i+SEQ_LEN])
        y.append(targets[i+SEQ_LEN])  # next quarter targets
        comp.append(company_id)

    return np.array(X), np.array(y), np.array(comp)

X_list, y_list, comp_list = [], [], []
for _, g in df.groupby(company_col):
    X_g, y_g, comp_g = create_sequences(g)
    if len(X_g) > 0:
        X_list.append(X_g)
        y_list.append(y_g)
        comp_list.append(comp_g)

X = np.vstack(X_list)
y = np.vstack(y_list)
companies = np.concatenate(comp_list)

print("Sequences shape:", X.shape, y.shape)

# ==============================
# 8. Train/Test Split
# ==============================
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train_raw, y_test_raw = y[:split], y[split:]
comp_train, comp_test = companies[:split], companies[split:]

# Fit y scaler on training targets and transform
y_train = scaler_y.fit_transform(y_train_raw)
y_test = scaler_y.transform(y_test_raw)

# ==============================
# 9. BiLSTM Model
# ==============================
num_companies = df["Company_Encoded"].nunique()
embed_dim = 8

input_seq = Input(shape=(SEQ_LEN, len(SEQ_FEATURES)))
input_comp = Input(shape=(1,))

# Company embedding
x_comp = Embedding(input_dim=num_companies, output_dim=embed_dim)(input_comp)
x_comp = Flatten()(x_comp)

# Sequence path
x_seq = Masking()(input_seq)
x_seq = Bidirectional(LSTM(64, return_sequences=True))(x_seq)
x_seq = Dropout(0.3)(x_seq)
x_seq = Bidirectional(LSTM(48))(x_seq)
x_seq = Dropout(0.2)(x_seq)

x = Concatenate()([x_seq, x_comp])

dense1 = Dense(64, activation="relu")(x)
dense1 = BatchNormalization()(dense1)
dense1 = Dropout(0.3)(dense1)
dense2 = Dense(32, activation="relu")(dense1)
dense2 = BatchNormalization()(dense2)
dense2 = Dropout(0.3)(dense2)

output = Dense(len(TARGETS))(dense2)

model = Model(inputs=[input_seq, input_comp], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mae")

model.summary()

# ==============================
# 10. Training
# ==============================
es = tf.keras.callbacks.EarlyStopping(patience=12, restore_best_weights=True)
rlr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=6, min_lr=1e-5)

history = model.fit(
    [X_train, comp_train],
    y_train,
    validation_split=0.2,
    epochs=120,
    batch_size=32,
    verbose=1,
    callbacks=[es, rlr]
)

# ==============================
# 11. Evaluation
# ==============================
preds_scaled = model.predict([X_test, comp_test])
preds = scaler_y.inverse_transform(preds_scaled)

print("\nMAE per Score:")
for i, col in enumerate(TARGETS):
    mae = mean_absolute_error(y_test_raw[:, i], preds[:, i])
    print(f"{col}: {mae:.4f}")

# ==============================
# 12. Visualization
# ==============================
n_plot = 200
plt.figure(figsize=(14, 8))
for i, col in enumerate(TARGETS):
    plt.subplot(2, 3, i+1)
    plt.plot(y_test_raw[:n_plot, i], label="Actual")
    plt.plot(preds[:n_plot, i], label="Predicted")
    plt.title(col)
    plt.legend()
plt.tight_layout()
plt.show()

# ==============================
# 13. Predict Future for a Company
# ==============================
def predict_future(company_name, df, model, scaler_X, scaler_y, SEQ_LEN=16):
    if company_name not in df[company_col].unique():
        raise ValueError(f"Company '{company_name}' not found in dataset.")

    company_data = df[df[company_col] == company_name].sort_values(by=date_col)
    company_id = company_data["Company_Encoded"].iloc[0]

    if len(company_data) < SEQ_LEN:
        raise ValueError(f"Not enough data for {company_name}. Need at least {SEQ_LEN} quarters.")

    last_seq = company_data[SEQ_FEATURES].values[-SEQ_LEN:]
    last_seq = np.expand_dims(last_seq, axis=0)

    pred_scaled = model.predict([last_seq, np.array([[company_id]])])
    pred = scaler_y.inverse_transform(pred_scaled)[0]

    return {col: round(val, 3) for col, val in zip(TARGETS, pred)}

# ==============================
# 14. Example Predictions
# ==============================
example_companies = df[company_col].unique()[:3]
for comp in example_companies:
    print(f"\nNext quarter prediction for {comp}:")
    print(predict_future(comp, df, model, scaler_X, scaler_y))
# Out:
# Data shape: (7574, 24)
# Columns: ['FiscalDate', 'Company', 'Sector', 'Revenue', 'Expenses', 'EBITDA', 'Operating Margin %', 'Depreciation', 'Interest', 'PBT', 'Tax', 'Net Profit', 'EPS', 'GST', 'CorpTax%', 'Inflation%', 'RepoRate%', 'USDINR_Close', 'Risk_Score', 'Growth_Score', 'Profitability_Score', 'Stability_Score', 'Sector_Score', 'Overall_Score']
# Sequences shape: (3927, 16, 11) (3927, 6)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 16, 11)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_8         │ (None, 16, 11)    │          0 │ input_layer_12[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_8 (Masking) │ (None, 16, 11)    │          0 │ input_layer_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_8 (Any)         │ (None, 16)        │          0 │ not_equal_8[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 16, 128)   │     38,912 │ masking_8[0][0],  │
# │ (Bidirectional)     │                   │            │ any_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 16, 128)   │          0 │ bidirectional_2[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_13      │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 96)        │     67,968 │ dropout_24[0][0], │
# │ (Bidirectional)     │                   │            │ any_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_6         │ (None, 1, 8)      │      1,944 │ input_layer_13[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 96)        │          0 │ bidirectional_3[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_8 (Flatten) │ (None, 8)         │          0 │ embedding_6[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 104)       │          0 │ dropout_25[0][0], │
# │ (Concatenate)       │                   │            │ flatten_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 64)        │      6,720 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 32)        │      2,080 │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 6)         │        198 │ dropout_27[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,206 (461.74 KB)
#  Trainable params: 118,014 (460.99 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - loss: 1.0185 - val_loss: 0.4344 - learning_rate: 0.0010
# Epoch 2/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.7091 - val_loss: 0.4285 - learning_rate: 0.0010
# Epoch 3/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.5621 - val_loss: 0.4069 - learning_rate: 0.0010
# Epoch 4/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.5479 - val_loss: 0.3956 - learning_rate: 0.0010
# Epoch 5/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.4671 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 6/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.4585 - val_loss: 0.3630 - learning_rate: 0.0010
# Epoch 7/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.4455 - val_loss: 0.3496 - learning_rate: 0.0010
# Epoch 8/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.4324 - val_loss: 0.3448 - learning_rate: 0.0010
# Epoch 9/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.4370 - val_loss: 0.3480 - learning_rate: 0.0010
# Epoch 10/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.4518 - val_loss: 0.3421 - learning_rate: 0.0010
# Epoch 11/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.4158 - val_loss: 0.3381 - learning_rate: 0.0010
# Epoch 12/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.4077 - val_loss: 0.3370 - learning_rate: 0.0010
# Epoch 13/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.4021 - val_loss: 0.3419 - learning_rate: 0.0010
# Epoch 14/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.4013 - val_loss: 0.3331 - learning_rate: 0.0010
# Epoch 15/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3895 - val_loss: 0.3321 - learning_rate: 0.0010
# Epoch 16/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3876 - val_loss: 0.3289 - learning_rate: 0.0010
# Epoch 17/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.3831 - val_loss: 0.3258 - learning_rate: 0.0010
# Epoch 18/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.3873 - val_loss: 0.3214 - learning_rate: 0.0010
# Epoch 19/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.3729 - val_loss: 0.3205 - learning_rate: 0.0010
# Epoch 20/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3834 - val_loss: 0.3173 - learning_rate: 0.0010
# Epoch 21/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3831 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 22/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.3607 - val_loss: 0.3163 - learning_rate: 0.0010
# Epoch 23/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.3682 - val_loss: 0.3206 - learning_rate: 0.0010
# Epoch 24/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.3626 - val_loss: 0.3148 - learning_rate: 0.0010
# Epoch 25/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.3590 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 26/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3535 - val_loss: 0.3106 - learning_rate: 0.0010
# Epoch 27/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.3687 - val_loss: 0.3120 - learning_rate: 0.0010
# Epoch 28/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.3715 - val_loss: 0.3084 - learning_rate: 0.0010
# Epoch 29/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.3603 - val_loss: 0.3122 - learning_rate: 0.0010
# Epoch 30/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3663 - val_loss: 0.3098 - learning_rate: 0.0010
# Epoch 31/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.3723 - val_loss: 0.3123 - learning_rate: 0.0010
# Epoch 32/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.3706 - val_loss: 0.3157 - learning_rate: 0.0010
# Epoch 33/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.3415 - val_loss: 0.3115 - learning_rate: 0.0010
# Epoch 34/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.3699 - val_loss: 0.3156 - learning_rate: 0.0010
# Epoch 35/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3627 - val_loss: 0.3114 - learning_rate: 5.0000e-04
# Epoch 36/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.3436 - val_loss: 0.3094 - learning_rate: 5.0000e-04
# Epoch 37/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.3355 - val_loss: 0.3076 - learning_rate: 5.0000e-04
# Epoch 38/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.3695 - val_loss: 0.3122 - learning_rate: 5.0000e-04
# Epoch 39/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.3575 - val_loss: 0.3104 - learning_rate: 5.0000e-04
# Epoch 40/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3368 - val_loss: 0.3124 - learning_rate: 5.0000e-04
# Epoch 41/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.3412 - val_loss: 0.3104 - learning_rate: 5.0000e-04
# Epoch 42/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.3367 - val_loss: 0.3119 - learning_rate: 5.0000e-04
# Epoch 43/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3513 - val_loss: 0.3133 - learning_rate: 5.0000e-04
# Epoch 44/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.3306 - val_loss: 0.3100 - learning_rate: 2.5000e-04
# Epoch 45/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.3333 - val_loss: 0.3102 - learning_rate: 2.5000e-04
# Epoch 46/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.3532 - val_loss: 0.3092 - learning_rate: 2.5000e-04
# Epoch 47/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3496 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 48/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.3392 - val_loss: 0.3096 - learning_rate: 2.5000e-04
# Epoch 49/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.3421 - val_loss: 0.3103 - learning_rate: 2.5000e-04
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
#
# MAE per Score:
# Risk_Score: 0.1278
# Growth_Score: 0.5246
# Profitability_Score: 0.2853
# Stability_Score: 0.2867
# Sector_Score: 0.4557
# Overall_Score: 0.3403
# Next quarter prediction for aarti-drugs-ltd:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3398277109.py in <cell line: 0>()
#     213 for comp in example_companies:
#     214     print(f"\nNext quarter prediction for {comp}:")
# --> 215     print(predict_future(comp, df, model, scaler_X, scaler_y))
#
# /tmp/ipython-input-3398277109.py in predict_future(company_name, df, model, scaler_X, scaler_y, SEQ_LEN)
#     202     last_seq = np.expand_dims(last_seq, axis=0)
#     203
# --> 204     pred_scaled = model.predict([last_seq, np.array([[company_id]])])
#     205     pred = scaler_y.inverse_transform(pred_scaled)[0]
#     206
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#     125
#     126     return error_handler
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
# ==============================
# 1. Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Embedding, LSTM, Dense, Concatenate, Dropout,
    Masking, Flatten, BatchNormalization, Bidirectional, Lambda
)

# ==============================
# 2. Load Data
# ==============================
file_path = "/content/final.xlsx"
df = pd.read_excel(file_path)

print("Data shape:", df.shape)
print("Columns:", df.columns.tolist())

# ==============================
# 3. Columns Setup
# ==============================
company_col = "Company"
date_col = "FiscalDate"

TARGETS = [
    "Risk_Score",
    "Growth_Score",
    "Profitability_Score",
    "Stability_Score",
    "Sector_Score",
    "Overall_Score",
]

MACRO_FEATURES = ["GST", "CorpTax%", "Inflation%", "RepoRate%", "USDINR_Close"]

SEQ_FEATURES = TARGETS + MACRO_FEATURES

# ==============================
# 4. Handle Missing Values
# ==============================
for col in SEQ_FEATURES:
    df[col] = df.groupby(company_col)[col].transform(lambda g: g.ffill().bfill())

df = df.dropna(subset=SEQ_FEATURES)

# ==============================
# 5. Encode Company
# ==============================
le = LabelEncoder()
df["Company_Encoded"] = le.fit_transform(df[company_col])

# ==============================
# 6. Scaling
# ==============================
# Scale only input features (X), NOT targets (since targets are already 0–100)
scaler_X = StandardScaler()
df[SEQ_FEATURES] = scaler_X.fit_transform(df[SEQ_FEATURES])

# ==============================
# 7. Sequence Builder (16 quarters)
# ==============================
SEQ_LEN = 16

def create_sequences(group):
    X, y, comp = [], [], []
    values = group[SEQ_FEATURES].values
    targets = group[TARGETS].values
    company_id = group["Company_Encoded"].values[0]

    for i in range(len(values) - SEQ_LEN):
        X.append(values[i:i+SEQ_LEN])
        y.append(targets[i+SEQ_LEN])  # next quarter targets
        comp.append(company_id)

    return np.array(X), np.array(y), np.array(comp)

X_list, y_list, comp_list = [], [], []
for _, g in df.groupby(company_col):
    X_g, y_g, comp_g = create_sequences(g)
    if len(X_g) > 0:
        X_list.append(X_g)
        y_list.append(y_g)
        comp_list.append(comp_g)

X = np.vstack(X_list)
y = np.vstack(y_list)
companies = np.concatenate(comp_list)

print("Sequences shape:", X.shape, y.shape)

# ==============================
# 8. Train/Test Split
# ==============================
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
comp_train, comp_test = companies[:split], companies[split:]

# ==============================
# 9. BiLSTM Model with sigmoid*100 output
# ==============================
num_companies = df["Company_Encoded"].nunique()
embed_dim = 8

input_seq = Input(shape=(SEQ_LEN, len(SEQ_FEATURES)))
input_comp = Input(shape=(1,), dtype="int32")

# Company embedding
x_comp = Embedding(input_dim=num_companies, output_dim=embed_dim)(input_comp)
x_comp = Flatten()(x_comp)

# Sequence path
x_seq = Masking()(input_seq)
x_seq = Bidirectional(LSTM(64, return_sequences=True))(x_seq)
x_seq = Dropout(0.3)(x_seq)
x_seq = Bidirectional(LSTM(48))(x_seq)
x_seq = Dropout(0.2)(x_seq)

x = Concatenate()([x_seq, x_comp])

dense1 = Dense(64, activation="relu")(x)
dense1 = BatchNormalization()(dense1)
dense1 = Dropout(0.3)(dense1)
dense2 = Dense(32, activation="relu")(dense1)
dense2 = BatchNormalization()(dense2)
dense2 = Dropout(0.3)(dense2)

# Final layer with sigmoid -> [0,1], then scale to [0,100]
out_sigmoid = Dense(len(TARGETS), activation="sigmoid")(dense2)
output = Lambda(lambda x: x * 100)(out_sigmoid)

model = Model(inputs=[input_seq, input_comp], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mae")

model.summary()

# ==============================
# 10. Training
# ==============================
es = tf.keras.callbacks.EarlyStopping(patience=12, restore_best_weights=True)
rlr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=6, min_lr=1e-5)

history = model.fit(
    [X_train, comp_train],
    y_train,
    validation_split=0.2,
    epochs=120,
    batch_size=32,
    verbose=1,
    callbacks=[es, rlr]
)

# ==============================
# 11. Evaluation
# ==============================
preds = model.predict([X_test, comp_test])

print("\nMAE per Score:")
for i, col in enumerate(TARGETS):
    mae = mean_absolute_error(y_test[:, i], preds[:, i])
    print(f"{col}: {mae:.4f}")

# ==============================
# 12. Visualization
# ==============================
n_plot = 200
plt.figure(figsize=(14, 8))
for i, col in enumerate(TARGETS):
    plt.subplot(2, 3, i+1)
    plt.plot(y_test[:n_plot, i], label="Actual")
    plt.plot(preds[:n_plot, i], label="Predicted")
    plt.title(col)
    plt.legend()
plt.tight_layout()
plt.show()

# ==============================
# 13. Predict Future for a Company
# ==============================
def predict_future(company_name, df, model, scaler_X, SEQ_LEN=16):
    if company_name not in df[company_col].unique():
        raise ValueError(f"Company '{company_name}' not found in dataset.")

    # Sort company data
    company_data = df[df[company_col] == company_name].sort_values(by=date_col)
    company_id = int(company_data["Company_Encoded"].iloc[0])

    if len(company_data) < SEQ_LEN:
        raise ValueError(f"Not enough data for {company_name}. Need at least {SEQ_LEN} quarters.")

    # Last sequence
    last_seq = company_data[SEQ_FEATURES].values[-SEQ_LEN:]
    last_seq = np.expand_dims(last_seq, axis=0)

    comp_input = np.array([[company_id]], dtype=np.int32)

    # Predict directly in 0–100
    pred = model.predict([last_seq, comp_input])[0]

    return {col: round(float(val), 2) for col, val in zip(TARGETS, pred)}

# ==============================
# 14. Example Predictions
# ==============================
example_companies = df[company_col].unique()[:3]
for comp in example_companies:
    print(f"\nNext quarter prediction for {comp}:")
    print(predict_future(comp, df, model, scaler_X))
# Out:
# Data shape: (7574, 24)
# Columns: ['FiscalDate', 'Company', 'Sector', 'Revenue', 'Expenses', 'EBITDA', 'Operating Margin %', 'Depreciation', 'Interest', 'PBT', 'Tax', 'Net Profit', 'EPS', 'GST', 'CorpTax%', 'Inflation%', 'RepoRate%', 'USDINR_Close', 'Risk_Score', 'Growth_Score', 'Profitability_Score', 'Stability_Score', 'Sector_Score', 'Overall_Score']
# Sequences shape: (3927, 16, 11) (3927, 6)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 16, 11)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_1         │ (None, 16, 11)    │          0 │ input_layer_2[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_1 (Masking) │ (None, 16, 11)    │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_1 (Any)         │ (None, 16)        │          0 │ not_equal_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 16, 128)   │     38,912 │ masking_1[0][0],  │
# │ (Bidirectional)     │                   │            │ any_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 128)   │          0 │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 96)        │     67,968 │ dropout_4[0][0],  │
# │ (Bidirectional)     │                   │            │ any_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 1, 8)      │      1,944 │ input_layer_3[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 96)        │          0 │ bidirectional_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 8)         │          0 │ embedding_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 104)       │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │                   │            │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │      6,720 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      2,080 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 6)         │        198 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 6)         │          0 │ dense_5[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,206 (461.74 KB)
#  Trainable params: 118,014 (460.99 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 74ms/step - loss: 47.7512 - val_loss: 33.7045 - learning_rate: 0.0010
# Epoch 2/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 33.9326 - val_loss: 14.0794 - learning_rate: 0.0010
# Epoch 3/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 19.1199 - val_loss: 8.9546 - learning_rate: 0.0010
# Epoch 4/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 12.7359 - val_loss: 2.7993 - learning_rate: 0.0010
# Epoch 5/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 9.2105 - val_loss: 3.6547 - learning_rate: 0.0010
# Epoch 6/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 9.2963 - val_loss: 1.7487 - learning_rate: 0.0010
# Epoch 7/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 7.6944 - val_loss: 0.8377 - learning_rate: 0.0010
# Epoch 8/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 5.4609 - val_loss: 1.1097 - learning_rate: 0.0010
# Epoch 9/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 5.2411 - val_loss: 0.6236 - learning_rate: 0.0010
# Epoch 10/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 5.0857 - val_loss: 0.5389 - learning_rate: 0.0010
# Epoch 11/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 4.4671 - val_loss: 1.1243 - learning_rate: 0.0010
# Epoch 12/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 3.5139 - val_loss: 0.4892 - learning_rate: 0.0010
# Epoch 13/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 3.1291 - val_loss: 0.4928 - learning_rate: 0.0010
# Epoch 14/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.7754 - val_loss: 0.5021 - learning_rate: 0.0010
# Epoch 15/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.1620 - val_loss: 0.4972 - learning_rate: 0.0010
# Epoch 16/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 1.3625 - val_loss: 0.4902 - learning_rate: 0.0010
# Epoch 17/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.0140 - val_loss: 0.4838 - learning_rate: 0.0010
# Epoch 18/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 0.8296 - val_loss: 0.4756 - learning_rate: 0.0010
# Epoch 19/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 0.6804 - val_loss: 0.4717 - learning_rate: 0.0010
# Epoch 20/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 0.8036 - val_loss: 0.4698 - learning_rate: 0.0010
# Epoch 21/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.7585 - val_loss: 0.4680 - learning_rate: 0.0010
# Epoch 22/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.7937 - val_loss: 0.4663 - learning_rate: 0.0010
# Epoch 23/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.7004 - val_loss: 0.4658 - learning_rate: 0.0010
# Epoch 24/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - loss: 0.7413 - val_loss: 0.4653 - learning_rate: 0.0010
# Epoch 25/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.6671 - val_loss: 0.4651 - learning_rate: 0.0010
# Epoch 26/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.7840 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 27/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.6285 - val_loss: 0.4645 - learning_rate: 0.0010
# Epoch 28/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 0.6014 - val_loss: 0.4639 - learning_rate: 0.0010
# Epoch 29/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.5264 - val_loss: 0.4642 - learning_rate: 0.0010
# Epoch 30/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 0.5434 - val_loss: 0.4641 - learning_rate: 0.0010
# Epoch 31/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.5006 - val_loss: 0.4636 - learning_rate: 0.0010
# Epoch 32/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.5092 - val_loss: 0.4636 - learning_rate: 0.0010
# Epoch 33/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.4924 - val_loss: 0.4635 - learning_rate: 0.0010
# Epoch 34/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.5074 - val_loss: 0.4632 - learning_rate: 0.0010
# Epoch 35/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.5130 - val_loss: 0.4632 - learning_rate: 0.0010
# Epoch 36/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.5185 - val_loss: 0.4631 - learning_rate: 0.0010
# Epoch 37/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.5301 - val_loss: 0.4632 - learning_rate: 0.0010
# Epoch 38/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.4965 - val_loss: 0.4631 - learning_rate: 0.0010
# Epoch 39/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.4820 - val_loss: 0.4630 - learning_rate: 0.0010
# Epoch 40/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - loss: 0.5023 - val_loss: 0.4630 - learning_rate: 0.0010
# Epoch 41/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.5232 - val_loss: 0.4630 - learning_rate: 0.0010
# Epoch 42/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.5066 - val_loss: 0.4629 - learning_rate: 0.0010
# Epoch 43/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.4818 - val_loss: 0.4629 - learning_rate: 0.0010
# Epoch 44/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 0.5036 - val_loss: 0.4628 - learning_rate: 0.0010
# Epoch 45/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.5113 - val_loss: 0.4628 - learning_rate: 0.0010
# Epoch 46/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.4753 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 47/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.5054 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 48/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.4880 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 49/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.5020 - val_loss: 0.4626 - learning_rate: 0.0010
# Epoch 50/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.4875 - val_loss: 0.4626 - learning_rate: 0.0010
# Epoch 51/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.5149 - val_loss: 0.4626 - learning_rate: 0.0010
# Epoch 52/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.4945 - val_loss: 0.4625 - learning_rate: 0.0010
# Epoch 53/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.4713 - val_loss: 0.4625 - learning_rate: 0.0010
# Epoch 54/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.4916 - val_loss: 0.4625 - learning_rate: 0.0010
# Epoch 55/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.5070 - val_loss: 0.4624 - learning_rate: 0.0010
# Epoch 56/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - loss: 0.4948 - val_loss: 0.4624 - learning_rate: 0.0010
# Epoch 57/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.5146 - val_loss: 0.4623 - learning_rate: 0.0010
# Epoch 58/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.4870 - val_loss: 0.4623 - learning_rate: 0.0010
# Epoch 59/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.4799 - val_loss: 0.4622 - learning_rate: 0.0010
# Epoch 60/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.4895 - val_loss: 0.4622 - learning_rate: 0.0010
# Epoch 61/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.4809 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 62/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.5063 - val_loss: 0.4620 - learning_rate: 0.0010
# Epoch 63/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.4893 - val_loss: 0.4620 - learning_rate: 0.0010
# Epoch 64/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.4907 - val_loss: 0.4619 - learning_rate: 0.0010
# Epoch 65/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.5020 - val_loss: 0.4618 - learning_rate: 0.0010
# Epoch 66/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.5152 - val_loss: 0.4617 - learning_rate: 0.0010
# Epoch 67/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.5075 - val_loss: 0.4616 - learning_rate: 0.0010
# Epoch 68/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.5075 - val_loss: 0.4615 - learning_rate: 0.0010
# Epoch 69/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.4929 - val_loss: 0.4615 - learning_rate: 0.0010
# Epoch 70/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.4862 - val_loss: 0.4614 - learning_rate: 0.0010
# Epoch 71/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.5241 - val_loss: 0.4612 - learning_rate: 0.0010
# Epoch 72/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.4918 - val_loss: 0.4611 - learning_rate: 0.0010
# Epoch 73/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.4892 - val_loss: 0.4608 - learning_rate: 0.0010
# Epoch 74/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.5373 - val_loss: 0.4608 - learning_rate: 0.0010
# Epoch 75/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.4882 - val_loss: 0.4606 - learning_rate: 0.0010
# Epoch 76/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 0.5075 - val_loss: 0.4605 - learning_rate: 0.0010
# Epoch 77/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.4695 - val_loss: 0.4604 - learning_rate: 0.0010
# Epoch 78/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.4734 - val_loss: 0.4603 - learning_rate: 0.0010
# Epoch 79/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.4710 - val_loss: 0.4601 - learning_rate: 0.0010
# Epoch 80/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.4994 - val_loss: 0.4599 - learning_rate: 0.0010
# Epoch 81/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.4862 - val_loss: 0.4596 - learning_rate: 0.0010
# Epoch 82/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4726 - val_loss: 0.4596 - learning_rate: 0.0010
# Epoch 83/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 0.4876 - val_loss: 0.4595 - learning_rate: 0.0010
# Epoch 84/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.5236 - val_loss: 0.4593 - learning_rate: 0.0010
# Epoch 85/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 0.5082 - val_loss: 0.4591 - learning_rate: 0.0010
# Epoch 86/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 0.4908 - val_loss: 0.4588 - learning_rate: 0.0010
# Epoch 87/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.4955 - val_loss: 0.4581 - learning_rate: 0.0010
# Epoch 88/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.4867 - val_loss: 0.4575 - learning_rate: 0.0010
# Epoch 89/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.4906 - val_loss: 0.4569 - learning_rate: 0.0010
# Epoch 90/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.4782 - val_loss: 0.4561 - learning_rate: 0.0010
# Epoch 91/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.4735 - val_loss: 0.4567 - learning_rate: 0.0010
# Epoch 92/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - loss: 0.4920 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 93/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 0.4967 - val_loss: 0.4559 - learning_rate: 0.0010
# Epoch 94/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.5064 - val_loss: 0.4559 - learning_rate: 0.0010
# Epoch 95/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 0.4874 - val_loss: 0.4546 - learning_rate: 0.0010
# Epoch 96/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.4782 - val_loss: 0.4540 - learning_rate: 0.0010
# Epoch 97/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.4724 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 98/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 0.4651 - val_loss: 0.4531 - learning_rate: 0.0010
# Epoch 99/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.4853 - val_loss: 0.4528 - learning_rate: 0.0010
# Epoch 100/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.4942 - val_loss: 0.4511 - learning_rate: 0.0010
# Epoch 101/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.4492 - val_loss: 0.4513 - learning_rate: 0.0010
# Epoch 102/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.5189 - val_loss: 0.4510 - learning_rate: 0.0010
# Epoch 103/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.4977 - val_loss: 0.4494 - learning_rate: 0.0010
# Epoch 104/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.4851 - val_loss: 0.4490 - learning_rate: 0.0010
# Epoch 105/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - loss: 0.5005 - val_loss: 0.4480 - learning_rate: 0.0010
# Epoch 106/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - loss: 0.4985 - val_loss: 0.4547 - learning_rate: 0.0010
# Epoch 107/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.4773 - val_loss: 0.4508 - learning_rate: 0.0010
# Epoch 108/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 0.4939 - val_loss: 0.4489 - learning_rate: 0.0010
# Epoch 109/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.4860 - val_loss: 0.4492 - learning_rate: 0.0010
# Epoch 110/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.4812 - val_loss: 0.4480 - learning_rate: 0.0010
# Epoch 111/120
# 75/79 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4866
